# %% [markdown]
# DATA VISULIZATION

# %% [markdown]
# MATPLOTLB

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
np.random.seed(20)
df=pd.DataFrame(np.random.rand(1000,1),index=pd.date_range('2021-03-18',periods=1000),columns=['data'])
df
# Out:
#                 data
# 2021-03-18  0.588131
# 2021-03-19  0.897714
# 2021-03-20  0.891531
# 2021-03-21  0.815837
# 2021-03-22  0.035890
# ...              ...
# 2023-12-08  0.992189
# 2023-12-09  0.756037
# 2023-12-10  0.299186
# 2023-12-11  0.261712
# 2023-12-12  0.968979
#
# [1000 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
df.plot()
plt.show()

# %%
#comulative sum
df.data.cumsum()
# Out:
# 2021-03-18      0.588131
# 2021-03-19      1.485845
# 2021-03-20      2.377375
# 2021-03-21      3.193213
# 2021-03-22      3.229102
#                  ...
# 2023-12-08    495.812936
# 2023-12-09    496.568973
# 2023-12-10    496.868159
# 2023-12-11    497.129872
# 2023-12-12    498.098851
# Freq: D, Name: data, Length: 1000, dtype: float64

# %%
df.data.cumsum().plot()
plt.show()

# %%
df['data1']=df.data.cumsum()

# %%
df['data2']=df['data'].apply(lambda x : x**3)

# %%
df
# Out:
#                 data       data1     data2
# 2021-03-18  0.588131    0.588131  0.203433
# 2021-03-19  0.897714    1.485845  0.723458
# 2021-03-20  0.891531    2.377375  0.708613
# 2021-03-21  0.815837    3.193213  0.543014
# 2021-03-22  0.035890    3.229102  0.000046
# ...              ...         ...       ...
# 2023-12-08  0.992189  495.812936  0.976749
# 2023-12-09  0.756037  496.568973  0.432145
# 2023-12-10  0.299186  496.868159  0.026781
# 2023-12-11  0.261712  497.129872  0.017926
# 2023-12-12  0.968979  498.098851  0.909794
#
# [1000 rows x 3 columns]

# %%
#can change the size of the plot
df.plot(figsize=(7,11))
plt.show()

# %%
#here we load a dataset from seaborn
df=sns.load_dataset('iris')

# %%
df.plot()
plt.show()

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
gf=df.plot(figsize=(7,7),title="irish data")
gf.set_xlabel("this is my x axis")
gf.set_ylabel("that's my y axis")
plt.show()

# %%
df.iloc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
df.iloc[0][0:4].plot(kind='bar',figsize=(3,3))
plt.show()

# %%
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['pclass'].plot(kind="bar")
plt.show()

# %%
df=pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.754462  0.591334  0.108692  0.402853
# 1  0.269676  0.573075  0.916855  0.189785
# 2  0.944349  0.820192  0.229638  0.697904
# 3  0.701251  0.570189  0.448045  0.332812
# 4  0.108018  0.121464  0.420368  0.336497
# 5  0.389588  0.301919  0.312265  0.036205
# 6  0.378922  0.010581  0.357048  0.083158
# 7  0.705395  0.816193  0.262531  0.382466
# 8  0.897100  0.437109  0.842188  0.852225
# 9  0.123356  0.150039  0.214021  0.006917

# %%
df.plot.bar()
plt.show()

# %%
df.plot.barh()
plt.show()

# %%
df.plot.hist()
plt.show()
